# %%
require 'notebooks/rails'
# Out:
# Loaded development environment
# true

# %%
SocialAnalytics::Analytics::Users.graduation_date
# Out:
# #<Daru::DataFrame:71229180 @name = dedfbc7e-dc2f-45fa-8784-7335b4205f9b @size = 1>
#                 y2013      y2014      y2015
# Year of gr        110        125         92

# %%
SocialAnalytics::Visualization::Users.graduation_date
# Out:
# #<GnuplotRB::Plot:0x00000008adac20 @options=Hamster::Hash[:style_data => "histograms", :ylabel => "Users", :title => "Graduation date statistics", :style_fill => "pattern border"], @datasets=Hamster::Vector[#<GnuplotRB::Dataset:0x00000008ada900 @type=:datablock, @data=#<GnuplotRB::Datablock:0x00000008ada5b8 @stored_in_file=false, @data="\"Year of graduation\" 110\n">, @options=Hamster::Hash[:using => "2:xtic(1)", :title => :y2013]>, #<GnuplotRB::Dataset:0x00000008ad9eb0 @type=:datablock, @data=#<GnuplotRB::Datablock:0x00000008ad9b90 @stored_in_file=false, @data="\"Year of graduation\" 125\n">, @options=Hamster::Hash[:using => "2:xtic(1)", :title => :y2014]>, #<GnuplotRB::Dataset:0x00000008ad9488 @type=:datablock, @data=#<GnuplotRB::Datablock:0x00000008ad9168 @stored_in_file=false, @data="\"Year of graduation\" 92\n">, @options=Hamster::Hash[:using => "2:xtic(1)", :title => :y2015]>], @cmd="plot ">

# %%
SocialAnalytics::Analytics::Users.sources
# Out:
# #<Daru::DataFrame:70836560 @name = d071692d-0e5b-408b-bee1-c8e4d50714c0 @size = 1>
#              Facebook     Github     Import   Linkedin
#    Sources        510        291        327         76

# %%
SocialAnalytics::Visualization::Users.sources
# Out:
# #<GnuplotRB::Plot:0x00000008d3d7b0 @options=Hamster::Hash[:style_data => "histograms", :ylabel => "Users", :title => "Sources statistics", :style_fill => "pattern border"], @datasets=Hamster::Vector[#<GnuplotRB::Dataset:0x00000008d3d490 @type=:datablock, @data=#<GnuplotRB::Datablock:0x00000008d3d170 @stored_in_file=false, @data="\"Sources\" 510\n">, @options=Hamster::Hash[:using => "2:xtic(1)", :title => :Facebook]>, #<GnuplotRB::Dataset:0x00000008d3ca68 @type=:datablock, @data=#<GnuplotRB::Datablock:0x00000008d3c748 @stored_in_file=false, @data="\"Sources\" 291\n">, @options=Hamster::Hash[:using => "2:xtic(1)", :title => :Github]>, #<GnuplotRB::Dataset:0x00000008d3c040 @type=:datablock, @data=#<GnuplotRB::Datablock:0x00000008567cc0 @stored_in_file=false, @data="\"Sources\" 327\n">, @options=Hamster::Hash[:using => "2:xtic(1)", :title => :Import]>, #<GnuplotRB::Dataset:0x000000085675b8 @type=:datablock, @data=#<GnuplotRB::Datablock:0x00000008567248 @stored_in_file=false, @data="\"Sou
# ...

# %%
SocialAnalytics::Analytics::Users.countries
# Out:
# #<Daru::DataFrame:67913560 @name = ae28bc6a-d4a3-4cc0-a876-774024cc7555 @size = 1>
#               Belgium     Canada    Germany     Israel Kazakhstan     Poland     Russia Russian Fe    Ukraine United Sta
#  Countries          3          1          1          1          3          1          4         18          5          1

# %%
SocialAnalytics::Visualization::Users.countries
# Out:
# #<GnuplotRB::Plot:0x00000007d9b6e0 @options=Hamster::Hash[:style_data => "histograms", :ylabel => "Users", :title => "Countries statistics (no Belarus)", :style_fill => "pattern border"], @datasets=Hamster::Vector[#<GnuplotRB::Dataset:0x00000007d9b3c0 @type=:datablock, @data=#<GnuplotRB::Datablock:0x00000007d9b078 @stored_in_file=false, @data="\"Countries\" 3\n">, @options=Hamster::Hash[:using => "2:xtic(1)", :title => :Belgium]>, #<GnuplotRB::Dataset:0x00000007d9a858 @type=:datablock, @data=#<GnuplotRB::Datablock:0x00000007d9a538 @stored_in_file=false, @data="\"Countries\" 1\n">, @options=Hamster::Hash[:using => "2:xtic(1)", :title => :Canada]>, #<GnuplotRB::Dataset:0x00000007d99e30 @type=:datablock, @data=#<GnuplotRB::Datablock:0x00000007d99ae8 @stored_in_file=false, @data="\"Countries\" 1\n">, @options=Hamster::Hash[:using => "2:xtic(1)", :title => :Germany]>, #<GnuplotRB::Dataset:0x00000007d992c8 @type=:datablock, @data=#<GnuplotRB::Datablock:0x00000007d98fa8 @stored_in_file=fals
# ...

# %%
SocialAnalytics::Analytics::Users.skills

# %%
SocialAnalytics::Visualization::Users.skills
