# %%
require 'notebooks/rails'
# Out:
# Loaded development environment
# true

# %%
SocialAnalytics::Analytics.graduation_date
# Out:
# #<Daru::DataFrame:30505040 @name = 505b36eb-7465-4d9c-be26-3bebc78d0464 @size = 1>
#                 y2013      y2014      y2015
# Year of gr        110        125         92

# %%
SocialAnalytics::Visualization.graduation_date
# Out:
# #<GnuplotRB::Plot:0x00000008855068 @options=Hamster::Hash[:style_fill => "pattern border", :style_data => "histograms", :title => "Graduation date statistics", :ylabel => "Users"], @datasets=Hamster::Vector[#<GnuplotRB::Dataset:0x00000008854cd0 @type=:datablock, @data=#<GnuplotRB::Datablock:0x00000008854988 @stored_in_file=false, @data="\"Year of graduation\" 110\n">, @options=Hamster::Hash[:title => :y2013, :using => "2:xtic(1)"]>, #<GnuplotRB::Dataset:0x000000088542f8 @type=:datablock, @data=#<GnuplotRB::Datablock:0x000000031c7ed0 @stored_in_file=false, @data="\"Year of graduation\" 125\n">, @options=Hamster::Hash[:title => :y2014, :using => "2:xtic(1)"]>, #<GnuplotRB::Dataset:0x0000000885fe78 @type=:datablock, @data=#<GnuplotRB::Datablock:0x0000000885fb58 @stored_in_file=false, @data="\"Year of graduation\" 92\n">, @options=Hamster::Hash[:title => :y2015, :using => "2:xtic(1)"]>], @cmd="plot ">

# %%
SocialAnalytics::Analytics.sources
# Out:
# #<Daru::DataFrame:70192580 @name = d8d38b56-3052-444c-b10a-8357fac9b5a1 @size = 1>
#              Facebook     Github     Import   Linkedin
#    Sources        510        291        327         76

# %%
SocialAnalytics::Visualization.sources
# Out:
# #<GnuplotRB::Plot:0x00000008ae5df0 @options=Hamster::Hash[:style_fill => "pattern border", :style_data => "histograms", :title => "Sources statistics", :ylabel => "Users"], @datasets=Hamster::Vector[#<GnuplotRB::Dataset:0x00000008ae5a58 @type=:datablock, @data=#<GnuplotRB::Datablock:0x00000008ae5738 @stored_in_file=false, @data="\"Sources\" 510\n">, @options=Hamster::Hash[:title => :Facebook, :using => "2:xtic(1)"]>, #<GnuplotRB::Dataset:0x00000008ae50a8 @type=:datablock, @data=#<GnuplotRB::Datablock:0x00000008ae4d88 @stored_in_file=false, @data="\"Sources\" 291\n">, @options=Hamster::Hash[:title => :Github, :using => "2:xtic(1)"]>, #<GnuplotRB::Dataset:0x00000008ae46f8 @type=:datablock, @data=#<GnuplotRB::Datablock:0x00000008ae43d8 @stored_in_file=false, @data="\"Sources\" 327\n">, @options=Hamster::Hash[:title => :Import, :using => "2:xtic(1)"]>, #<GnuplotRB::Dataset:0x00000008333d00 @type=:datablock, @data=#<GnuplotRB::Datablock:0x000000083339e0 @stored_in_file=false, @data="\"Sou
# ...

# %%
SocialAnalytics::Analytics.countries
# Out:
# #<Daru::DataFrame:66712500 @name = c0daff91-8dc2-40a9-a503-cc5425782b96 @size = 1>
#               Belgium     Canada    Germany     Israel Kazakhstan     Poland     Russia Russian Fe    Ukraine United Sta
#  Countries          3          1          1          1          3          1          4         18          5          1

# %%
SocialAnalytics::Visualization.countries
# Out:
# #<GnuplotRB::Plot:0x00000007b46fe8 @options=Hamster::Hash[:style_fill => "pattern border", :style_data => "histograms", :title => "Countries statistics (no Belarus)", :ylabel => "Users"], @datasets=Hamster::Vector[#<GnuplotRB::Dataset:0x00000007b46c50 @type=:datablock, @data=#<GnuplotRB::Datablock:0x00000007b46908 @stored_in_file=false, @data="\"Countries\" 3\n">, @options=Hamster::Hash[:title => :Belgium, :using => "2:xtic(1)"]>, #<GnuplotRB::Dataset:0x00000007b46160 @type=:datablock, @data=#<GnuplotRB::Datablock:0x00000007b45e40 @stored_in_file=false, @data="\"Countries\" 1\n">, @options=Hamster::Hash[:title => :Canada, :using => "2:xtic(1)"]>, #<GnuplotRB::Dataset:0x00000007b45670 @type=:datablock, @data=#<GnuplotRB::Datablock:0x00000007b45350 @stored_in_file=false, @data="\"Countries\" 1\n">, @options=Hamster::Hash[:title => :Germany, :using => "2:xtic(1)"]>, #<GnuplotRB::Dataset:0x00000007b44c98 @type=:datablock, @data=#<GnuplotRB::Datablock:0x00000007b44860 @stored_in_file=fals
# ...

# %%
SocialAnalytics::Analytics.languages_in_repos
# Out:
# #<Daru::DataFrame:63833080 @name = 84636042-3c22-4daa-a218-ab4a1f696867 @size = 97>
#            repositori
# JavaScript        474
#        CSS        402
#       HTML        311
#       Ruby        286
#      Shell        192
#        C++        155
#       Java        154
#         C#        152
#     Python        145
#          C        119
# CoffeeScri        104
# Objective-         69
#   Makefile         65
#        PHP         53
#        ASP         39
#        ...        ...

# %%
SocialAnalytics::Visualization.languages_in_repos
# Out:
# #<GnuplotRB::Plot:0x00000003fd0720 @options=Hamster::Hash[:style_fill => "pattern border", :style_data => "histograms", :xtics => "nomirror rotate by -45", :title => "Repositories count by language", :ylabel => "Repositories", :term => ["pngcairo", {:size=>[5000, 600]}]], @datasets=Hamster::Vector[#<GnuplotRB::Dataset:0x00000003fc38e0 @type=:datablock, @data=#<GnuplotRB::Datablock:0x00000003fc2f08 @stored_in_file=false, @data="\"JavaScript\" 474\n\"CSS\" 402\n\"HTML\" 311\n\"Ruby\" 286\n\"Shell\" 192\n\"C++\" 155\n\"Java\" 154\n\"C#\" 152\n\"Python\" 145\n\"C\" 119\n\"CoffeeScript\" 104\n\"Objective-C\" 69\n\"Makefile\" 65\n\"PHP\" 53\n\"ASP\" 39\n\"Perl\" 35\n\"Batchfile\" 32\n\"CMake\" 27\n\"Swift\" 26\n\"QMake\" 19\n\"ApacheConf\" 18\n\"VimL\" 16\n\"R\" 15\n\"Assembly\" 13\n\"Groovy\" 13\n\"Scala\" 12\n\"XSLT\" 12\n\"Go\" 12\n\"Cucumber\" 11\n\"TeX\" 10\n\"Ada\" 10\n\"PowerShell\" 9\n\"Prolog\" 9\n\"Lua\" 8\n\"Emacs Lisp\" 8\n\"Groff\" 8\n\"Arduino\" 8\n\"XML\" 8\n\"Kotlin\" 7\n\"
# ...

# %%
SocialAnalytics::Analytics.skills
# Out:
# #<Daru::DataFrame:67481980 @name = de67ace8-46ac-4f07-8273-a77d041b7aa7 @size = 100>
#                skills
#        C++         28
# JavaScript         24
#        Git         22
#        SQL         22
#       HTML         20
#         C#         19
#       Java         15
#          C         15
#        CSS         13
#      MySQL         13
#        XML         11
#     jQuery         11
#        PHP         11
#       .NET         10
# Software D          9
#        ...        ...

# %%
SocialAnalytics::Visualization.skills
# Out:
# #<GnuplotRB::Plot:0x0000000867a090 @options=Hamster::Hash[:style_fill => "pattern border", :style_data => "histograms", :xtics => "nomirror rotate by -45", :title => "Skills (linkedin)", :ylabel => "Users", :term => ["pngcairo", {:size=>[5000, 600]}]], @datasets=Hamster::Vector[#<GnuplotRB::Dataset:0x00000008679ca8 @type=:datablock, @data=#<GnuplotRB::Datablock:0x00000008679988 @stored_in_file=false, @data="\"C++\" 28\n\"JavaScript\" 24\n\"Git\" 22\n\"SQL\" 22\n\"HTML\" 20\n\"C#\" 19\n\"Java\" 15\n\"C\" 15\n\"CSS\" 13\n\"MySQL\" 13\n\"XML\" 11\n\"jQuery\" 11\n\"PHP\" 11\n\".NET\" 10\n\"Software Development\" 9\n\"Linux\" 8\n\"ASP.NET MVC\" 8\n\"Project Management\" 8\n\"Agile Methodologies\" 7\n\"Objective-C\" 6\n\"Ruby on Rails\" 6\n\"Ruby\" 6\n\"Visual Studio\" 6\n\"OOP\" 6\n\"Scrum\" 5\n\"Python\" 5\n\"Subversion\" 5\n\"Microsoft SQL Server\" 5\n\"Photoshop\" 4\n\"Unity3D\" 4\n\"TCP/IP\" 4\n\"iOS development\" 4\n\"Yii\" 4\n\"Multithreading\" 4\n\"Tortoise SVN\" 4\n\"Windows\" 4\n
# ...

# %%
SocialAnalytics::Analytics.companies_countries
# Out:
# #<Daru::DataFrame:68431060 @name = dee39b70-ffbf-4c5b-958c-cd3998d86e2a @size = 12>
#             companies
# United Sta         16
#    Belarus         10
# Russian Fe         10
#    Belgium          4
# United Kin          3
#     Cyprus          2
#     Israel          1
#     Poland          1
#  Lithuania          1
# Switzerlan          1
#    Germany          1
#     Norway          1

# %%
SocialAnalytics::Visualization.companies_countries
# Out:
# #<GnuplotRB::Plot:0x000000078376e0 @options=Hamster::Hash[:style_fill => "pattern border", :style_data => "histograms", :xtics => "nomirror rotate by -45", :title => "Companies in country statistics", :ylabel => "Companies"], @datasets=Hamster::Vector[#<GnuplotRB::Dataset:0x00000007836a60 @type=:datablock, @data=#<GnuplotRB::Datablock:0x000000078362e0 @stored_in_file=false, @data="\"United States\" 16\n\"Belarus\" 10\n\"Russian Federation\" 10\n\"Belgium\" 4\n\"United Kingdom\" 3\n\"Cyprus\" 2\n\"Israel\" 1\n\"Poland\" 1\n\"Lithuania\" 1\n\"Switzerland\" 1\n\"Germany\" 1\n\"Norway\" 1\n">, @options=Hamster::Hash[:title => :companies, :using => "2:xtic(1)"]>], @cmd="plot ">

# %%
SocialAnalytics::Analytics.company_sizes
# Out:
# #<Daru::DataFrame:46594520 @name = b7fc02a6-8d1f-4ea4-ae2f-7014c8480a6f @size = 9>
#             companies
# Myself Onl          1
# 1-10 emplo          2
# 10,001+ em          7
# 11-50 empl         10
# 51-200 emp         14
# 201-500 em          4
# 501-1000 e          2
# 1001-5000          11
# 5001-10,00          2

# %%
SocialAnalytics::Visualization.company_sizes
# Out:
# #<GnuplotRB::Plot:0x00000003d23a18 @options=Hamster::Hash[:style_fill => "pattern border", :style_data => "histograms", :xtics => "nomirror rotate by -45", :title => "Company sizes", :ylabel => "Companies"], @datasets=Hamster::Vector[#<GnuplotRB::Dataset:0x00000003d220c8 @type=:datablock, @data=#<GnuplotRB::Datablock:0x00000003d21290 @stored_in_file=false, @data="\"Myself Only\" 1\n\"1-10 employees\" 2\n\"10,001+ employees\" 7\n\"11-50 employees\" 10\n\"51-200 employees\" 14\n\"201-500 employees\" 4\n\"501-1000 employees\" 2\n\"1001-5000 employees\" 11\n\"5001-10,000 employees\" 2\n">, @options=Hamster::Hash[:title => :companies, :using => "2:xtic(1)"]>], @cmd="plot ">
